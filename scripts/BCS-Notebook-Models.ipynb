# %%
import pandas as pd 
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Import and Split

# %%
df_to_models = pd.read_csv(r'../data/to_models.csv', index_col=0)
y = pd.read_csv(r'../data/y.csv', index_col=0)

# %%
# creating train/val and test dataframes 
X_train_val, X_test, y_train_val, y_test = train_test_split(df_to_models, 
                                                    y, 
                                                    test_size=0.2, 
                                                    random_state=15, 
                                                    shuffle=True, 
                                                    stratify=y
                                                   )

# creating train and val 
X_train, X_val, y_train, y_val = train_test_split(X_train_val,
                                                  y_train_val,
                                                  test_size = 0.25,
                                                  random_state = 15,
                                                  shuffle=True,
                                                  stratify=y_train_val
)

# %%
print('train:{}% | validation:{}% | test:{}%'.format(round(len(y_train)/len(y),2),
                                                     round(len(y_val)/len(y),2),
                                                     round(len(y_test)/len(y),2)
                                                    ))
# Out:
# train:0.6% | validation:0.2% | test:0.2%

# %% [markdown]
# ## Logistic Regression

# %%
X_train
# Out:
#             ADR  BookingChanges  DaysInWaitingList  LeadTime  \
# 73979  0.290549       -0.356694          -0.085647 -0.204681
# 20407 -0.319147       -0.356694          -0.085647 -0.289915
# 69810  2.383629       -0.356694          -0.085647 -0.789143
# 57732  3.431217        2.597993          -0.085647 -0.947435
# 38894 -0.947700       -0.356694          -0.085647 -0.910906
# ...         ...             ...                ...       ...
# 47681  0.162743       -0.356694          -0.085647 -0.910906
# 10454 -0.246863       -0.356694          -0.085647  0.525896
# 57684  1.000813       -0.356694          -0.085647 -0.886554
# 66147 -0.465809       -0.356694          -0.085647 -0.923083
# 46527 -0.098525       -0.356694          -0.085647 -0.375149
#
#        PreviousBookingsNotCanceled  PreviousCancellations  \
# 73979                    -0.093792              -0.095888
# 20407                    -0.093792              -0.095888
# 69810                    -0.093792              -0.095888
# 57732                    -0.093792              -0.095888
# 38894                     3.334803              -0.095888
# ...                            ...                    ...
# 47681                    -0.093792              -0.095888
# 10454                    -0.093792              -0.095888
# 57684                    -0.093792              -0.095888
# 66147                     0.396008              -0.095888
# 46527                    -0.093792              -0.095888
#
#        StaysInWeekendNights  StaysInWeekNights  TotalOfSpecialRequests  \
# 73979              1.247805           0.458536               -0.853318
# 20407              0.142691          -0.170971                0.346706
# 69810              1.247805          -1.429985                0.346706
# 57732             -0.962422          -0.800478               -0.853318
# 38894             -0.962422          -0.800478               -0.853318
# ...                     ...                ...                     ...
# 47681              0.142691          -1.429985                1.546731
# 10454              0.142691           0.458536                0.346706
# 57684              0.142691          -1.429985                0.346706
# 66147             -0.962422          -0.800478                1.546731
# 46527              1.247805           1.088043                1.546731
#
#          Adults  ...  x11_avg_booker  x11_bin_booker  x11_good_booker  \
# 73979  2.098466  ...             1.0             0.0              0.0
# 20407  0.223842  ...             0.0             0.0              0.0
# 69810  0.223842  ...             0.0             0.0              0.0
# 57732  0.223842  ...             0.0             0.0              0.0
# 38894 -1.650782  ...             0.0             0.0              0.0
# ...         ...  ...             ...             ...              ...
# 47681  0.223842  ...             0.0             0.0              0.0
# 10454  0.223842  ...             0.0             0.0              0.0
# 57684 -1.650782  ...             0.0             0.0              0.0
# 66147 -1.650782  ...             0.0             0.0              0.0
# 46527  0.223842  ...             0.0             0.0              0.0
#
#        x11_low_booker  x11_no_booker  x11_super_booker  x12_Autumn  \
# 73979             0.0            0.0               0.0         0.0
# 20407             0.0            0.0               1.0         1.0
# 69810             0.0            0.0               1.0         0.0
# 57732             0.0            1.0               0.0         1.0
# 38894             0.0            1.0               0.0         0.0
# ...               ...            ...               ...         ...
# 47681             0.0            0.0               1.0         0.0
# 10454             0.0            0.0               1.0         0.0
# 57684             0.0            0.0               1.0         1.0
# 66147             0.0            1.0               0.0         0.0
# 46527             0.0            0.0               1.0         0.0
#
#        x12_Spring  x12_Summer  x12_Winter
# 73979         0.0         1.0         0.0
# 20407         0.0         0.0         0.0
# 69810         1.0         0.0         0.0
# 57732         0.0         0.0         0.0
# 38894         0.0         0.0         1.0
# ...           ...         ...         ...
# 47681         1.0         0.0         0.0
# 10454         1.0         0.0         0.0
# 57684         0.0         0.0         0.0
# 66147         1.0         0.0         0.0
# 46527         1.0         0.0         0.0
#
# [31938 rows x 279 columns]
