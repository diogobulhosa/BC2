# %%
import pandas as pd
import numpy as np 

# models 
from sklearn.linear_model import LogisticRegression

#metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,f1_score
from sklearn.model_selection import RepeatedStratifiedKFold

#smote 
from imblearn.over_sampling import SMOTE

# data
from sklearn.model_selection import train_test_split

#ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Import and Split

# %%
df_to_models = pd.read_csv(r'../data/to_models.csv', index_col=0)
y = pd.read_csv(r'../data/y.csv', index_col=0)

# %%
# creating train/val and test dataframes 
X_train_val, X_test, y_train_val, y_test = train_test_split(df_to_models, 
                                                    y, 
                                                    test_size=0.2, 
                                                    random_state=15, 
                                                    shuffle=True, 
                                                    stratify=y
                                                   )

# %% [markdown]
# # Functions to Test Models

# %%
def metrics(X_train, X_val, y_train, pred_train , y_val, pred_val, model):
    print('___________________________________________________________________________________________________________')
    print('                                                     TRAIN                                                 ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_train, pred_train))
    print(confusion_matrix(y_train, pred_train))
    print("Score: "+ str(model.score(X_train, y_train)))
    print("F1 Score: "+ str(f1_score(y_train, pred_train)))

    print('___________________________________________________________________________________________________________')
    print('                                                VALIDATION                                                 ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_val, pred_val))
    print(confusion_matrix(y_val, pred_val))
    print("Score: "+ str(model.score(X_val, y_val)))
    print("F1 Score: "+ str(f1_score(y_val, pred_val)))

# %%
def avg_score(model, data_to_slice, y_to_slice, columns_to_use, smote = False):
    # apply kfold
    skf = RepeatedStratifiedKFold(n_splits=10, n_repeats=10)
    # create lists to store the results from the different models 
    score_train = []
    score_test = []
    f1_list = []

    for train_index, test_index in skf.split(data_to_slice[columns_to_use],y_to_slice):
        # get the indexes of the observations assigned for each partition
        X_train, X_val = data_to_slice[columns_to_use].iloc[train_index], data_to_slice[columns_to_use].iloc[test_index]
        y_train, y_val = y_to_slice.iloc[train_index], y.iloc[test_index]
        
        # SMOTE É AQUI 
        if smote: 
            smote = SMOTE(random_state = 11)
            X_train, y_train = smote.fit_resample(X_train, y_train)


        # applies the model 
        model_fit = model.fit(X_train, y_train)
        # predicts training 
        y_pred_train =  model_fit.predict(X_train)
        #predicts validation 
        y_pred_val = model_fit.predict(X_val)
        # prints metric results 
        
        #metrics(X_train, X_val, y_train, y_pred_train, y_val, y_pred_val, model)
        
        value_train = model.score(X_train, y_train)
        # check the mean accuracy for the test
        value_test = model.score(X_val,y_val)
        f1_score_val = f1_score(y_val, y_pred_val)
        # append the accuracies, the time and the number of iterations in the corresponding list
        score_train.append(value_train)
        score_test.append(value_test)
        f1_list.append(f1_score_val)
  
    avg_train = round(np.mean(score_train),3)
    avg_test = round(np.mean(score_test),3)
    std_train = round(np.std(score_train),2)
    std_test = round(np.std(score_test),2)
    avg_f1 = round(np.mean(f1_list),3)
    std_f1 = round(np.std(f1_list),2)
    #print(confusion_matrix(y_val, y_pred_val))

    return str(avg_train) + '+/-' + str(std_train),\
            str(avg_test) + '+/-' + str(std_test) , str(avg_f1) + '+/-' + str(std_f1), avg_f1

# %% [markdown]
# ## Logistic Regression

# %%
LogReg = LogisticRegression()

avg_score(LogReg, X_train_val, y_train_val,X_train_val.columns, True )
# Out:
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26719
#            1       0.73      0.74      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19306  7413]
#  [ 7078 19641]]
# Score: 0.7288259291141136
# F1 Score: 0.7305153143771038
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.59      0.60      2627
#            1       0.38      0.40      0.39      1622
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.52      0.52      0.52      4249
#
# [[1542 1085]
#  [ 966  656]]
# Score: 0.5172981878088962
# F1 Score: 0.3901278620279513
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19296  7422]
#  [ 7136 19582]]
# Score: 0.727561943259226
# F1 Score: 0.7290123226983357
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.58      0.60      2677
#            1       0.36      0.40      0.38      1572
#
#     accuracy                           0.52      4249
#    macro avg       0.49      0.49      0.49      4249
# weighted avg       0.53      0.52      0.52      4249
#
# [[1559 1118]
#  [ 936  636]]
# Score: 0.5165921393269004
# F1 Score: 0.38244137101623576
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19331  7387]
#  [ 7091 19627]]
# Score: 0.7290590613069841
# F1 Score: 0.7305516265912305
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.60      2656
#            1       0.37      0.40      0.38      1593
#
#     accuracy                           0.52      4249
#    macro avg       0.49      0.49      0.49      4249
# weighted avg       0.52      0.52      0.52      4249
#
# [[1554 1102]
#  [ 957  636]]
# Score: 0.5154153918569075
# F1 Score: 0.3818673071149805
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19352  7366]
#  [ 7012 19706]]
# Score: 0.7309304588666816
# F1 Score: 0.7327012455846811
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.61      2638
#            1       0.38      0.40      0.39      1611
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.53      0.52      0.52      4249
#
# [[1566 1072]
#  [ 963  648]]
# Score: 0.5210637797128737
# F1 Score: 0.3890723506454518
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19286  7432]
#  [ 7010 19708]]
# Score: 0.7297327644284752
# F1 Score: 0.7318504214787033
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.60      0.57      0.59      2574
#            1       0.39      0.42      0.40      1675
#
#     accuracy                           0.51      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.52      0.51      0.52      4249
#
# [[1474 1100]
#  [ 971  704]]
# Score: 0.5125911979289245
# F1 Score: 0.4047139982753665
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19366  7352]
#  [ 7002 19716]]
# Score: 0.7313795942810091
# F1 Score: 0.7331275796675715
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.60      0.61      2624
#            1       0.40      0.43      0.42      1625
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.54      0.53      0.54      4249
#
# [[1562 1062]
#  [ 921  704]]
# Score: 0.5333019534008002
# F1 Score: 0.4152167502211737
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19306  7412]
#  [ 7065 19653]]
# Score: 0.729077775282581
# F1 Score: 0.7308257256010263
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.59      0.61      2687
#            1       0.38      0.43      0.40      1562
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1578 1109]
#  [ 893  669]]
# Score: 0.528830313014827
# F1 Score: 0.40059880239520956
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19325  7393]
#  [ 7099 19619]]
# Score: 0.7287970656486263
# F1 Score: 0.7302810348036478
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.60      0.62      2725
#            1       0.37      0.42      0.39      1524
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.55      0.53      0.54      4249
#
# [[1624 1101]
#  [ 884  640]]
# Score: 0.532831254412803
# F1 Score: 0.39203675344563554
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73     26719
#            1       0.73      0.74      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19341  7378]
#  [ 6944 19775]]
# Score: 0.7319884726224783
# F1 Score: 0.7341476091476093
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.61      0.62      2645
#            1       0.39      0.42      0.40      1603
#
#     accuracy                           0.53      4248
#    macro avg       0.51      0.51      0.51      4248
# weighted avg       0.54      0.53      0.54      4248
#
# [[1601 1044]
#  [ 932  671]]
# Score: 0.5348399246704332
# F1 Score: 0.40446051838456903
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26719
#            1       0.73      0.73      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19331  7388]
#  [ 7185 19534]]
# Score: 0.7272914405479247
# F1 Score: 0.7283234839022389
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.61      2643
#            1       0.38      0.41      0.39      1605
#
#     accuracy                           0.52      4248
#    macro avg       0.50      0.50      0.50      4248
# weighted avg       0.53      0.52      0.53      4248
#
# [[1570 1073]
#  [ 953  652]]
# Score: 0.5230696798493408
# F1 Score: 0.39159159159159157
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73     26719
#            1       0.73      0.74      0.74     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19365  7354]
#  [ 6921 19798]]
# Score: 0.7328679965567574
# F1 Score: 0.7350151287334558
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61      2619
#            1       0.40      0.42      0.41      1630
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1579 1040]
#  [ 949  681]]
# Score: 0.5318898564368086
# F1 Score: 0.40644583706356313
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.72      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19226  7492]
#  [ 7072 19646]]
# Score: 0.7274496594056441
# F1 Score: 0.7295751633986927
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61      2665
#            1       0.38      0.42      0.40      1584
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.50      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1577 1088]
#  [ 919  665]]
# Score: 0.5276535655448341
# F1 Score: 0.39856158225951455
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19330  7388]
#  [ 7072 19646]]
# Score: 0.7293959128677296
# F1 Score: 0.7309867539812471
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61      2628
#            1       0.39      0.41      0.40      1621
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1585 1043]
#  [ 951  670]]
# Score: 0.5307131089668157
# F1 Score: 0.4019196160767846
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19297  7421]
#  [ 7078 19640]]
# Score: 0.7286660678194475
# F1 Score: 0.730396623217241
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.57      0.59      2642
#            1       0.37      0.41      0.39      1607
#
#     accuracy                           0.51      4249
#    macro avg       0.49      0.49      0.49      4249
# weighted avg       0.52      0.51      0.52      4249
#
# [[1510 1132]
#  [ 945  662]]
# Score: 0.5111791009649329
# F1 Score: 0.3892972655101441
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19371  7347]
#  [ 7083 19635]]
# Score: 0.7299573321356388
# F1 Score: 0.7312849162011174
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61      2656
#            1       0.38      0.42      0.40      1593
#
#     accuracy                           0.53      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.53      0.53      0.53      4249
#
# [[1570 1086]
#  [ 930  663]]
# Score: 0.5255354200988468
# F1 Score: 0.3967684021543986
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19292  7426]
#  [ 7105 19613]]
# Score: 0.7280672206003443
# F1 Score: 0.7296910169838345
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61      2667
#            1       0.37      0.41      0.39      1582
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.53      0.52      0.53      4249
#
# [[1564 1103]
#  [ 933  649]]
# Score: 0.520828430218875
# F1 Score: 0.3893221355728854
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19319  7399]
#  [ 7133 19585]]
# Score: 0.7280485066247474
# F1 Score: 0.7293955532382406
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.57      0.59      2679
#            1       0.36      0.41      0.38      1570
#
#     accuracy                           0.51      4249
#    macro avg       0.49      0.49      0.49      4249
# weighted avg       0.52      0.51      0.51      4249
#
# [[1517 1162]
#  [ 926  644]]
# Score: 0.5085902565309485
# F1 Score: 0.3815165876777251
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19394  7324]
#  [ 6989 19729]]
# Score: 0.7321468672804851
# F1 Score: 0.7338156255230514
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.60      0.61      2653
#            1       0.38      0.42      0.40      1596
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1586 1067]
#  [ 932  664]]
# Score: 0.5295363614968228
# F1 Score: 0.3991584009618274
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26719
#            1       0.73      0.74      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19362  7357]
#  [ 7031 19688]]
# Score: 0.7307533964594484
# F1 Score: 0.732385983185775
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61      2651
#            1       0.38      0.41      0.39      1597
#
#     accuracy                           0.52      4248
#    macro avg       0.50      0.50      0.50      4248
# weighted avg       0.53      0.52      0.53      4248
#
# [[1576 1075]
#  [ 945  652]]
# Score: 0.524482109227872
# F1 Score: 0.39229843561973526
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.72     26719
#            1       0.72      0.73      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19270  7449]
#  [ 7229 19490]]
# Score: 0.7253265466521951
# F1 Score: 0.7264527190726452
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61      2636
#            1       0.38      0.41      0.39      1612
#
#     accuracy                           0.53      4248
#    macro avg       0.50      0.50      0.50      4248
# weighted avg       0.53      0.53      0.53      4248
#
# [[1592 1044]
#  [ 959  653]]
# Score: 0.5284839924670434
# F1 Score: 0.39468117255968566
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26719
#            1       0.73      0.74      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19338  7381]
#  [ 7057 19662]]
# Score: 0.7298177326995771
# F1 Score: 0.7314460027528737
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61      2628
#            1       0.39      0.44      0.41      1621
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1539 1089]
#  [ 912  709]]
# Score: 0.5290656625088256
# F1 Score: 0.41474115238373793
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.72      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19286  7432]
#  [ 7134 19584]]
# Score: 0.7274122314544502
# F1 Score: 0.728923958759817
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61      2679
#            1       0.37      0.42      0.39      1570
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.54      0.52      0.53      4249
#
# [[1572 1107]
#  [ 915  655]]
# Score: 0.5241233231348552
# F1 Score: 0.39315726290516206
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19421  7297]
#  [ 6959 19759]]
# Score: 0.7332135638895126
# F1 Score: 0.7348904675121806
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.60      0.61      2674
#            1       0.37      0.41      0.39      1575
#
#     accuracy                           0.53      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.53      0.53      0.53      4249
#
# [[1594 1080]
#  [ 935  640]]
# Score: 0.5257707695928454
# F1 Score: 0.3884673748103187
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19346  7372]
#  [ 7093 19625]]
# Score: 0.7293023429897447
# F1 Score: 0.730708368239784
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.61      0.63      2686
#            1       0.39      0.42      0.40      1563
#
#     accuracy                           0.54      4249
#    macro avg       0.52      0.52      0.51      4249
# weighted avg       0.55      0.54      0.54      4249
#
# [[1639 1047]
#  [ 905  658]]
# Score: 0.5405977877147564
# F1 Score: 0.4026927784577724
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19282  7436]
#  [ 6998 19720]]
# Score: 0.729882476233251
# F1 Score: 0.732078553662249
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.61      2644
#            1       0.38      0.41      0.40      1605
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.53      0.52      0.53      4249
#
# [[1557 1087]
#  [ 939  666]]
# Score: 0.5231819251588609
# F1 Score: 0.3966646813579512
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19327  7391]
#  [ 7195 19523]]
# Score: 0.7270379519425106
# F1 Score: 0.7280355011933175
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.58      0.60      2589
#            1       0.39      0.42      0.41      1660
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.53      0.52      0.52      4249
#
# [[1513 1076]
#  [ 963  697]]
# Score: 0.5201223817368793
# F1 Score: 0.4060588406641421
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19283  7435]
#  [ 7083 19635]]
# Score: 0.728310502283105
# F1 Score: 0.7300884955752213
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.61      2665
#            1       0.37      0.40      0.38      1584
#
#     accuracy                           0.52      4249
#    macro avg       0.49      0.49      0.49      4249
# weighted avg       0.53      0.52      0.52      4249
#
# [[1575 1090]
#  [ 956  628]]
# Score: 0.5184749352788891
# F1 Score: 0.38037552998182916
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19298  7420]
#  [ 7133 19585]]
# Score: 0.7276555131372109
# F1 Score: 0.729110436870614
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.57      0.60      2687
#            1       0.36      0.42      0.39      1562
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.53      0.52      0.52      4249
#
# [[1545 1142]
#  [ 908  654]]
# Score: 0.5175335373028948
# F1 Score: 0.3895175699821322
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26719
#            1       0.73      0.73      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19347  7372]
#  [ 7090 19629]]
# Score: 0.7293686140948389
# F1 Score: 0.7307892777364111
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.61      2642
#            1       0.38      0.41      0.39      1606
#
#     accuracy                           0.52      4248
#    macro avg       0.50      0.50      0.50      4248
# weighted avg       0.53      0.52      0.53      4248
#
# [[1568 1074]
#  [ 949  657]]
# Score: 0.5237758945386064
# F1 Score: 0.39376685645789633
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26719
#            1       0.73      0.74      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19354  7365]
#  [ 6998 19721]]
# Score: 0.731221228339384
# F1 Score: 0.7330545488337515
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.59      0.60      2602
#            1       0.38      0.39      0.38      1646
#
#     accuracy                           0.51      4248
#    macro avg       0.49      0.49      0.49      4248
# weighted avg       0.52      0.51      0.51      4248
#
# [[1539 1063]
#  [1004  642]]
# Score: 0.5134180790960452
# F1 Score: 0.38316920322291853
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26719
#            1       0.73      0.73      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19321  7398]
#  [ 7118 19601]]
# Score: 0.7283580972341779
# F1 Score: 0.7297740049890168
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.60      0.62      2687
#            1       0.37      0.42      0.39      1562
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1603 1084]
#  [ 912  650]]
# Score: 0.5302424099788186
# F1 Score: 0.3944174757281554
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19392  7326]
#  [ 7018 19700]]
# Score: 0.7315667340369788
# F1 Score: 0.7331050908008336
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.58      0.61      2707
#            1       0.36      0.42      0.39      1542
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.54      0.52      0.53      4249
#
# [[1571 1136]
#  [ 891  651]]
# Score: 0.5229465756648624
# F1 Score: 0.3911084409732652
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19340  7378]
#  [ 7015 19703]]
# Score: 0.730649749232727
# F1 Score: 0.732467146229484
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# ...
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19297  7421]
#  [ 7047 19671]]
# Score: 0.7292462010629538
# F1 Score: 0.7311280431146628
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.59      0.61      2699
#            1       0.37      0.42      0.39      1550
#
#     accuracy                           0.53      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1586 1113]
#  [ 897  653]]
# Score: 0.5269475170628383
# F1 Score: 0.3938480096501809
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73     26719
#            1       0.73      0.74      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19417  7302]
#  [ 6978 19741]]
# Score: 0.7327744301807703
# F1 Score: 0.7343848815148246
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.59      0.60      2649
#            1       0.36      0.38      0.37      1599
#
#     accuracy                           0.51      4248
#    macro avg       0.49      0.49      0.49      4248
# weighted avg       0.52      0.51      0.52      4248
#
# [[1566 1083]
#  [ 986  613]]
# Score: 0.5129472693032016
# F1 Score: 0.37207890743550837
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73     26719
#            1       0.73      0.74      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19411  7308]
#  [ 7031 19688]]
# Score: 0.7316703469441221
# F1 Score: 0.7330540817276366
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.61      2643
#            1       0.38      0.41      0.40      1605
#
#     accuracy                           0.52      4248
#    macro avg       0.50      0.50      0.50      4248
# weighted avg       0.53      0.52      0.53      4248
#
# [[1564 1079]
#  [ 943  662]]
# Score: 0.5240112994350282
# F1 Score: 0.3956963538553497
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26719
#            1       0.73      0.74      0.73     26719
#
#     accuracy                           0.73     53438
#    macro avg       0.73      0.73      0.73     53438
# weighted avg       0.73      0.73      0.73     53438
#
# [[19359  7360]
#  [ 7071 19648]]
# Score: 0.729948725625959
# F1 Score: 0.7314013438308485
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.59      0.61      2673
#            1       0.38      0.43      0.41      1576
#
#     accuracy                           0.53      4249
#    macro avg       0.51      0.51      0.51      4249
# weighted avg       0.54      0.53      0.54      4249
#
# [[1568 1105]
#  [ 891  685]]
# Score: 0.5302424099788186
# F1 Score: 0.4070112893642306
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19371  7347]
#  [ 7077 19641]]
# Score: 0.7300696159892207
# F1 Score: 0.7314266562395262
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61      2665
#            1       0.37      0.40      0.39      1584
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.53      0.52      0.53      4249
#
# [[1577 1088]
#  [ 946  638]]
# Score: 0.5212991292068722
# F1 Score: 0.3854984894259819
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19330  7388]
#  [ 6962 19756]]
# Score: 0.7314544501833969
# F1 Score: 0.7335784040696596
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61      2690
#            1       0.37      0.42      0.39      1559
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.54      0.52      0.53      4249
#
# [[1574 1116]
#  [ 905  654]]
# Score: 0.5243586726288538
# F1 Score: 0.392910784019225
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19286  7432]
#  [ 7068 19650]]
# Score: 0.7286473538438506
# F1 Score: 0.7304832713754646
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.57      0.59      2632
#            1       0.37      0.41      0.39      1617
#
#     accuracy                           0.51      4249
#    macro avg       0.49      0.49      0.49      4249
# weighted avg       0.52      0.51      0.51      4249
#
# [[1497 1135]
#  [ 960  657]]
# Score: 0.5069428100729584
# F1 Score: 0.385450278674098
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73     26718
#            1       0.73      0.74      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19353  7365]
#  [ 6947 19771]]
# Score: 0.732165581256082
# F1 Score: 0.7342444386675084
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.59      0.62      2708
#            1       0.37      0.42      0.39      1541
#
#     accuracy                           0.53      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.54      0.53      0.53      4249
#
# [[1604 1104]
#  [ 900  641]]
# Score: 0.5283596140268298
# F1 Score: 0.3901399878271455
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73     26718
#            1       0.73      0.73      0.73     26718
#
#     accuracy                           0.73     53436
#    macro avg       0.73      0.73      0.73     53436
# weighted avg       0.73      0.73      0.73     53436
#
# [[19365  7353]
#  [ 7123 19595]]
# Score: 0.729096489258178
# F1 Score: 0.7302575187269407
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.59      0.60      2621
#            1       0.38      0.41      0.39      1628
#
#     accuracy                           0.52      4249
#    macro avg       0.50      0.50      0.50      4249
# weighted avg       0.52      0.52      0.52      4249
#
# [[1534 1087]
#  [ 963  665]]
# Score: 0.5175335373028948
# F1 Score: 0.393491124260355
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/x8/rchg54g91cl4k7n26xkn8mq80000gn/T/ipykernel_83325/4205319769.py in <module>
#       1 LogReg = LogisticRegression()
#       2
# ----> 3 avg_score(LogReg, X_train_val, y_train_val,X_train_val.columns, True )
#
# /var/folders/x8/rchg54g91cl4k7n26xkn8mq80000gn/T/ipykernel_83325/4225669195.py in avg_score(model, data_to_slice, y_to_slice, columns_to_use, smote)
#      15         if smote:
#      16             smote = SMOTE(random_state = 11)
# ---> 17             X_train, y_train = smote.fit_resample(X_train, y_train)
#      18
#      19
#
# ~/opt/anaconda3/envs/BC/lib/python3.8/site-packages/imblearn/base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = (
#
# ~/opt/anaconda3/envs/BC/lib/python3.8/site-packages/imblearn/over_sampling/_smote/base.py in _fit_resample(self, X, y)
#     322
#     323             self.nn_k_.fit(X_class)
# --> 324             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     325             X_new, y_new = self._make_samples(
#     326                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# ~/opt/anaconda3/envs/BC/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     750                 kwds = self.effective_metric_params_
#     751
# --> 752             chunked_results = list(
#     753                 pairwise_distances_chunked(
#     754                     X,
#
# ~/opt/anaconda3/envs/BC/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1724         if reduce_func is not None:
#    1725             chunk_size = D_chunk.shape[0]
# -> 1726             D_chunk = reduce_func(D_chunk, sl.start)
#    1727             _check_chunk_size(D_chunk, chunk_size)
#    1728         yield D_chunk
#
# ~/opt/anaconda3/envs/BC/lib/python3.8/site-packages/sklearn/neighbors/_base.py in _kneighbors_reduce_func(self, dist, start, n_neighbors, return_distance)
#     632         """
#     633         sample_range = np.arange(dist.shape[0])[:, None]
# --> 634         neigh_ind = np.argpartition(dist, n_neighbors - 1, axis=1)
#     635         neigh_ind = neigh_ind[:, :n_neighbors]
#     636         # argpartition doesn't guarantee sorted order, so we sort again
#
# <__array_function__ internals> in argpartition(*args, **kwargs)
#
# ~/opt/anaconda3/envs/BC/lib/python3.8/site-packages/numpy/core/fromnumeric.py in argpartition(a, kth, axis, kind, order)
#     837
#     838     """
# --> 839     return _wrapfunc(a, 'argpartition', kth, axis=axis, kind=kind, order=order)
#     840
#     841
#
# ~/opt/anaconda3/envs/BC/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:
